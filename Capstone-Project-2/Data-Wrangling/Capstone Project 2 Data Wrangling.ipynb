# %% [markdown]
# This is the data wrangling part of my capstone project 2.  The data was all downloaded from www.naturalstattrick.com, a website containing a lot of data pertaining to NHL hockey games.  From the players tab, I am using the On-Ice, Individual, and Bios data from the seasons 2007-08 to 2017-18.  I will probably put in many .head() and .info() commands to make sure the data is forming the way I want it to.

# %%
import pandas as pd
import numpy as np

# %%
# I'll start by loading the bio data

df_bio_0708 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals bios 2007-8.csv')

# Let's see what this looks like

df_bio_0708.head()
# Out:
#    Unnamed: 0         Player Team Position  Age Date of Birth  \
# 0         NaN   Aaron Downey  DET        R   43    1974-08-27
# 1         NaN  Aaron Johnson  NYI        D   35    1983-04-30
# 2         NaN   Aaron Miller  VAN        D   46    1971-08-11
# 3         NaN     Aaron Rome  CBJ        D   34    1983-09-27
# 4         NaN    Aaron Voros  MIN        L   36    1981-07-02
#
#         Birth City Birth State/Province Birth Country Nationality  \
# 0        Shelburne                   ON           CAN         CAN
# 1  Port Hawkesbury                   NS           CAN         CAN
# 2          Buffalo                   NY           USA         USA
# 3          Nesbitt                   MB           CAN         CAN
# 4        Vancouver                   BC           CAN         CAN
#
#    Height (in)  Weight (lbs) Draft Year Draft Team Draft Round Round Pick  \
# 0           73           215          -          -           -          -
# ...

# %%
# I don't need that first blank column

df_bio_0708 = df_bio_0708.drop(df_bio_0708.columns[0], axis=1)

df_bio_0708.head()
# Out:
#           Player Team Position  Age Date of Birth       Birth City  \
# 0   Aaron Downey  DET        R   43    1974-08-27        Shelburne
# 1  Aaron Johnson  NYI        D   35    1983-04-30  Port Hawkesbury
# 2   Aaron Miller  VAN        D   46    1971-08-11          Buffalo
# 3     Aaron Rome  CBJ        D   34    1983-09-27          Nesbitt
# 4    Aaron Voros  MIN        L   36    1981-07-02        Vancouver
#
#   Birth State/Province Birth Country Nationality  Height (in)  Weight (lbs)  \
# 0                   ON           CAN         CAN           73           215
# 1                   NS           CAN         CAN           73           204
# 2                   NY           USA         USA           75           210
# 3                   MB           CAN         CAN           73           220
# 4                   BC           CAN         CAN           74           210
#
#   Draft Year Draft Team Draft Round Round Pick Overall Draft Position
# ...

# %%
df_bio_0809 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals bios 2008-9.csv')
df_bio_0910 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals bios 2009-10.csv')
df_bio_1011 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals bios 2010-11.csv')
df_bio_1112 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals bios 2011-12.csv')
df_bio_1213 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals bios 2012-13.csv')
df_bio_1314 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals bios 2013-14.csv')
df_bio_1415 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals bios 2014-15.csv')
df_bio_1516 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals bios 2015-16.csv')
df_bio_1617 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals bios 2016-17.csv')
df_bio_1718 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals bios 2017-18.csv')

df_bio_0809 = df_bio_0809.drop(df_bio_0809.columns[0], axis=1)
df_bio_0910 = df_bio_0910.drop(df_bio_0910.columns[0], axis=1)
df_bio_1011 = df_bio_1011.drop(df_bio_1011.columns[0], axis=1)
df_bio_1112 = df_bio_1112.drop(df_bio_1112.columns[0], axis=1)
df_bio_1213 = df_bio_1213.drop(df_bio_1213.columns[0], axis=1)
df_bio_1314 = df_bio_1314.drop(df_bio_1314.columns[0], axis=1)
df_bio_1415 = df_bio_1415.drop(df_bio_1415.columns[0], axis=1)
df_bio_1516 = df_bio_1516.drop(df_bio_1516.columns[0], axis=1)
df_bio_1617 = df_bio_1617.drop(df_bio_1617.columns[0], axis=1)
df_bio_1718 = df_bio_1718.drop(df_bio_1718.columns[0], axis=1)

# Let's look at another, just to compare to the first

df_bio_1718.head()
# Out:
#             Player      Team Position  Age Date of Birth     Birth City  \
# 0       A.J. Greer       COL        L   21    1996-12-14       Joliette
# 1     Aaron Ekblad       FLA        D   22    1996-02-07        Windsor
# 2       Aaron Ness       WSH        D   28    1990-05-18         Roseau
# 3  Adam Clendening       ARI        D   25    1992-10-26  Niagara Falls
# 4   Adam Cracknell  DAL, NYR        R   32    1985-07-15  Prince Albert
#
#   Birth State/Province Birth Country Nationality  Height (in)  Weight (lbs)  \
# 0                   QC           CAN         CAN           75           204
# 1                   ON           CAN         CAN           76           216
# 2                   MN           USA         USA           70           184
# 3                   NY           USA         USA           72           196
# 4                   SK           CAN         CAN           74           218
#
#   Draft Year Draft Team Draft Round Round Pick Overall Draft Position
# ...

# %%
# How many players' birth country is not their nationality?

birth_not_nat = (df_bio_1718['Birth Country'] != df_bio_1718['Nationality'])

print(np.sum(birth_not_nat))
# Out:
# 23

# %% [markdown]
# 23 out of almost 900 is not enough to be worried about.  I'll just keep nationality for simplicity.

# %%
# For this study, I don't need age (I have birth date), I don't care where any players are born, or what team drafted them
# or what exact spot they were drafted at

df_bio_0708 = df_bio_0708.drop(['Age','Birth City','Birth State/Province','Birth Country','Draft Team','Round Pick','Overall Draft Position'], axis=1)
df_bio_0708.head()
# Out:
#           Player Team Position Date of Birth Nationality  Height (in)  \
# 0   Aaron Downey  DET        R    1974-08-27         CAN           73
# 1  Aaron Johnson  NYI        D    1983-04-30         CAN           73
# 2   Aaron Miller  VAN        D    1971-08-11         USA           75
# 3     Aaron Rome  CBJ        D    1983-09-27         CAN           73
# 4    Aaron Voros  MIN        L    1981-07-02         CAN           74
#
#    Weight (lbs) Draft Year Draft Round
# 0           215          -           -
# 1           204       2001           3
# 2           210       1989           5
# 3           220       2002           4
# 4           210       2001           8

# %%
df_bio_0809 = df_bio_0809.drop(['Age','Birth City','Birth State/Province','Birth Country','Draft Team','Round Pick','Overall Draft Position'], axis=1)
df_bio_0910 = df_bio_0910.drop(['Age','Birth City','Birth State/Province','Birth Country','Draft Team','Round Pick','Overall Draft Position'], axis=1)
df_bio_1011 = df_bio_1011.drop(['Age','Birth City','Birth State/Province','Birth Country','Draft Team','Round Pick','Overall Draft Position'], axis=1)
df_bio_1112 = df_bio_1112.drop(['Age','Birth City','Birth State/Province','Birth Country','Draft Team','Round Pick','Overall Draft Position'], axis=1)
df_bio_1213 = df_bio_1213.drop(['Age','Birth City','Birth State/Province','Birth Country','Draft Team','Round Pick','Overall Draft Position'], axis=1)
df_bio_1314 = df_bio_1314.drop(['Age','Birth City','Birth State/Province','Birth Country','Draft Team','Round Pick','Overall Draft Position'], axis=1)
df_bio_1415 = df_bio_1415.drop(['Age','Birth City','Birth State/Province','Birth Country','Draft Team','Round Pick','Overall Draft Position'], axis=1)
df_bio_1516 = df_bio_1516.drop(['Age','Birth City','Birth State/Province','Birth Country','Draft Team','Round Pick','Overall Draft Position'], axis=1)
df_bio_1617 = df_bio_1617.drop(['Age','Birth City','Birth State/Province','Birth Country','Draft Team','Round Pick','Overall Draft Position'], axis=1)
df_bio_1718 = df_bio_1718.drop(['Age','Birth City','Birth State/Province','Birth Country','Draft Team','Round Pick','Overall Draft Position'], axis=1)

df_bio_1718.head()
# Out:
#             Player      Team Position Date of Birth Nationality  Height (in)  \
# 0       A.J. Greer       COL        L    1996-12-14         CAN           75
# 1     Aaron Ekblad       FLA        D    1996-02-07         CAN           76
# 2       Aaron Ness       WSH        D    1990-05-18         USA           70
# 3  Adam Clendening       ARI        D    1992-10-26         USA           72
# 4   Adam Cracknell  DAL, NYR        R    1985-07-15         CAN           74
#
#    Weight (lbs) Draft Year Draft Round
# 0           204       2015           2
# 1           216       2014           1
# 2           184       2008           2
# 3           196       2011           2
# 4           218       2004           9

# %%
# Now let's see if any data is missing

df_bio_0708.info()
df_bio_0809.info()
df_bio_0910.info()
df_bio_1011.info()
df_bio_1112.info()
df_bio_1213.info()
df_bio_1314.info()
df_bio_1415.info()
df_bio_1516.info()
df_bio_1617.info()
df_bio_1718.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 9 columns):
# Player           852 non-null object
# Team             852 non-null object
# Position         852 non-null object
# Date of Birth    852 non-null object
# Nationality      852 non-null object
# Height (in)      852 non-null int64
# Weight (lbs)     852 non-null int64
# Draft Year       852 non-null object
# Draft Round      852 non-null object
# dtypes: int64(2), object(7)
# memory usage: 60.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885 entries, 0 to 884
# Data columns (total 9 columns):
# Player           885 non-null object
# Team             885 non-null object
# Position         885 non-null object
# Date of Birth    885 non-null object
# Nationality      885 non-null object
# Height (in)      885 non-null int64
# Weight (lbs)     885 non-null int64
# Draft Year       885 non-null object
# Draft Round      885 non-null object
# ...

# %% [markdown]
# Good, it looks like there are no null values in any of the remaining data.

# %%
# Now I'll load the first part of the statistics

df_0708 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2007-8.csv')

df_0708.head()
# Out:
#    Unnamed: 0         Player Team Position  GP         TOI   CF   CA    CF%  \
# 0         NaN   Aaron Downey  DET        R  56  256.933333  196  191  50.65
# 1         NaN  Aaron Johnson  NYI        D  30  415.850000  370  349  51.46
# 2         NaN   Aaron Miller  VAN        D  57  988.183333  639  955  40.09
# 3         NaN     Aaron Rome  CBJ        D  17  309.033333  223  240  48.16
# 4         NaN    Aaron Voros  MIN        L  55  504.600000  413  432  48.88
#
#     FF         ...           HDGF  HDGA  HDGF%  On-Ice SH%  On-Ice SV%    PDO  \
# 0  160         ...              4     4  50.00        5.22       93.86  0.991
# 1  258         ...              8     9  47.06       10.71       91.24  1.020
# 2  486         ...             15    25  37.50        9.48       90.52  1.000
# 3  176         ...              3     8  27.27        4.58       89.86  0.944
# 4  309         ...             16    12  57.14       11.47       89.84  1.013
#
# ...

# %%
# Again, don't need that first column

df_0708 = df_0708.drop(df_0708.columns[0], axis=1)

df_0708.head()
# Out:
#           Player Team Position  GP         TOI   CF   CA    CF%   FF   FA  \
# 0   Aaron Downey  DET        R  56  256.933333  196  191  50.65  160  153
# 1  Aaron Johnson  NYI        D  30  415.850000  370  349  51.46  258  263
# 2   Aaron Miller  VAN        D  57  988.183333  639  955  40.09  486  724
# 3     Aaron Rome  CBJ        D  17  309.033333  223  240  48.16  176  182
# 4    Aaron Voros  MIN        L  55  504.600000  413  432  48.88  309  344
#
#           ...           HDGF  HDGA  HDGF%  On-Ice SH%  On-Ice SV%    PDO  \
# 0         ...              4     4  50.00        5.22       93.86  0.991
# 1         ...              8     9  47.06       10.71       91.24  1.020
# 2         ...             15    25  37.50        9.48       90.52  1.000
# 3         ...              3     8  27.27        4.58       89.86  0.944
# 4         ...             16    12  57.14       11.47       89.84  1.013
#
#    Off. Zone Faceoffs  Neu. Zone Faceoffs  Def. Zone Faceoffs  \
# ...

# %%
df_0809 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2008-9.csv')
df_0910 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2009-10.csv')
df_1011 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2010-11.csv')
df_1112 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2011-12.csv')
df_1213 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2012-13.csv')
df_1314 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2013-14.csv')
df_1415 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2014-15.csv')
df_1516 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2015-16.csv')
df_1617 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2016-17.csv')
df_1718 = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2017-18.csv')

df_0809 = df_0809.drop(df_0809.columns[0], axis=1)
df_0910 = df_0910.drop(df_0910.columns[0], axis=1)
df_1011 = df_1011.drop(df_1011.columns[0], axis=1)
df_1112 = df_1112.drop(df_1112.columns[0], axis=1)
df_1213 = df_1213.drop(df_1213.columns[0], axis=1)
df_1314 = df_1314.drop(df_1314.columns[0], axis=1)
df_1415 = df_1415.drop(df_1415.columns[0], axis=1)
df_1516 = df_1516.drop(df_1516.columns[0], axis=1)
df_1617 = df_1617.drop(df_1617.columns[0], axis=1)
df_1718 = df_1718.drop(df_1718.columns[0], axis=1)

# And again, look at another one

df_1718.head()
# Out:
#             Player      Team Position  GP          TOI    CF    CA    CF%  \
# 0       A.J. Greer       COL        L  17   125.683333    88   129  40.55
# 1     Aaron Ekblad       FLA        D  82  1917.900000  1937  2037  48.74
# 2       Aaron Ness       WSH        D   8   101.816667    78   111  41.27
# 3  Adam Clendening       ARI        D   5    79.666667    79    91  46.47
# 4   Adam Cracknell  DAL, NYR        R   5    38.550000    27    36  42.86
#
#      FF    FA         ...           HDGF  HDGA  HDGF%  On-Ice SH%  On-Ice SV%  \
# 0    68   100         ...              2     1  66.67        7.41       97.26
# 1  1531  1609         ...             57    58  49.57       10.32       91.45
# 2    63    90         ...              1     3  25.00       12.50       92.06
# 3    62    68         ...              3     4  42.86        8.89       87.76
# 4    18    29         ...              0     1   0.00        0.00       91.67
#
# ...

# %%
df_0708.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 33 columns):
# Player                 852 non-null object
# Team                   852 non-null object
# Position               852 non-null object
# GP                     852 non-null int64
# TOI                    852 non-null float64
# CF                     852 non-null int64
# CA                     852 non-null int64
# CF%                    852 non-null float64
# FF                     852 non-null int64
# FA                     852 non-null int64
# FF%                    852 non-null float64
# SF                     852 non-null int64
# SA                     852 non-null int64
# SF%                    852 non-null float64
# GF                     852 non-null int64
# GA                     852 non-null int64
# GF%                    852 non-null float64
# SCF                    852 non-null int64
# SCA                    852 non-null int64
# ...

# %%
# For this study, I'm more interested in the percentages than the pure numbers and I already have the player info in the
# bio dataframe

df_0708 = df_0708.drop(['Team','Position','CF','CA','FF','FA','SF','SA','GF','GA','SCF','SCA','HDCF','HDCA','HDGF','HDGA','On-Ice SH%','On-Ice SV%'], axis=1)

df_0708.head()
# Out:
#           Player  GP         TOI    CF%    FF%    SF%    GF%   SCF%  HDCF%  \
# 0   Aaron Downey  56  256.933333  50.65  51.12  50.22  46.15  45.09  46.05
# 1  Aaron Johnson  30  415.850000  51.46  49.52  50.26  55.26  52.16  46.09
# 2   Aaron Miller  57  988.183333  40.09  40.17  40.23  40.24  41.50  42.39
# 3     Aaron Rome  17  309.033333  48.16  49.16  48.70  30.00  52.09  50.55
# 4    Aaron Voros  55  504.600000  48.88  47.32  46.98  50.00  49.63  51.59
#
#    HDGF%    PDO  Off. Zone Faceoffs  Neu. Zone Faceoffs  Def. Zone Faceoffs  \
# 0  50.00  0.991                 104                  67                  22
# 1  47.06  1.020                 115                 145                  91
# 2  37.50  1.000                 160                 306                 298
# 3  27.27  0.944                  58                  97                  82
# 4  57.14  1.013                 158                 205                 144
#
#    Off. Zone Faceoff %
# 0                82.54
# ...

# %%
df_0809 = df_0809.drop(['Team','Position','CF','CA','FF','FA','SF','SA','GF','GA','SCF','SCA','HDCF','HDCA','HDGF','HDGA','On-Ice SH%','On-Ice SV%'], axis=1)
df_0910 = df_0910.drop(['Team','Position','CF','CA','FF','FA','SF','SA','GF','GA','SCF','SCA','HDCF','HDCA','HDGF','HDGA','On-Ice SH%','On-Ice SV%'], axis=1)
df_1011 = df_1011.drop(['Team','Position','CF','CA','FF','FA','SF','SA','GF','GA','SCF','SCA','HDCF','HDCA','HDGF','HDGA','On-Ice SH%','On-Ice SV%'], axis=1)
df_1112 = df_1112.drop(['Team','Position','CF','CA','FF','FA','SF','SA','GF','GA','SCF','SCA','HDCF','HDCA','HDGF','HDGA','On-Ice SH%','On-Ice SV%'], axis=1)
df_1213 = df_1213.drop(['Team','Position','CF','CA','FF','FA','SF','SA','GF','GA','SCF','SCA','HDCF','HDCA','HDGF','HDGA','On-Ice SH%','On-Ice SV%'], axis=1)
df_1314 = df_1314.drop(['Team','Position','CF','CA','FF','FA','SF','SA','GF','GA','SCF','SCA','HDCF','HDCA','HDGF','HDGA','On-Ice SH%','On-Ice SV%'], axis=1)
df_1415 = df_1415.drop(['Team','Position','CF','CA','FF','FA','SF','SA','GF','GA','SCF','SCA','HDCF','HDCA','HDGF','HDGA','On-Ice SH%','On-Ice SV%'], axis=1)
df_1516 = df_1516.drop(['Team','Position','CF','CA','FF','FA','SF','SA','GF','GA','SCF','SCA','HDCF','HDCA','HDGF','HDGA','On-Ice SH%','On-Ice SV%'], axis=1)
df_1617 = df_1617.drop(['Team','Position','CF','CA','FF','FA','SF','SA','GF','GA','SCF','SCA','HDCF','HDCA','HDGF','HDGA','On-Ice SH%','On-Ice SV%'], axis=1)
df_1718 = df_1718.drop(['Team','Position','CF','CA','FF','FA','SF','SA','GF','GA','SCF','SCA','HDCF','HDCA','HDGF','HDGA','On-Ice SH%','On-Ice SV%'], axis=1)

df_1718.head()
# Out:
#             Player  GP          TOI    CF%    FF%    SF%    GF%   SCF%  HDCF%  \
# 0       A.J. Greer  17   125.683333  40.55  40.48  42.52  66.67  46.00  39.53
# 1     Aaron Ekblad  82  1917.900000  48.74  48.76  48.06  52.75  49.16  44.10
# 2       Aaron Ness   8   101.816667  41.27  41.18  43.24  54.55  40.86  22.58
# 3  Adam Clendening   5    79.666667  46.47  47.69  47.87  40.00  42.22  42.86
# 4   Adam Cracknell   5    38.550000  42.86  38.30  36.84   0.00  34.78  30.00
#
#    HDGF%    PDO  Off. Zone Faceoffs  Neu. Zone Faceoffs  Def. Zone Faceoffs  \
# 0  66.67  1.047                  36                  34                  33
# 1  49.57  1.018                 622                 663                 892
# 2  25.00  1.046                  20                  37                  32
# 3  42.86  0.966                  21                  28                  25
# 4   0.00  0.917                   7                  11                  12
#
#    Off. Zone Faceoff %
# ...

# %%
# If we bother to track Off. Zone %, why not all 3 zones?

df_0708['Off Zone Faceoff %'] = df_0708['Off.\xa0Zone Faceoffs']*100/(df_0708['Off.\xa0Zone Faceoffs'] + df_0708['Neu.\xa0Zone Faceoffs'] + df_0708['Def.\xa0Zone Faceoffs'])
df_0708['Def Zone Faceoff %'] = df_0708['Def.\xa0Zone Faceoffs']*100/(df_0708['Off.\xa0Zone Faceoffs'] + df_0708['Neu.\xa0Zone Faceoffs'] + df_0708['Def.\xa0Zone Faceoffs'])
df_0708['Neu Zone Faceoff %'] = df_0708['Neu.\xa0Zone Faceoffs']*100/(df_0708['Off.\xa0Zone Faceoffs'] + df_0708['Neu.\xa0Zone Faceoffs'] + df_0708['Def.\xa0Zone Faceoffs'])

df_0708 = df_0708.drop(['Off.\xa0Zone Faceoffs','Def.\xa0Zone Faceoffs','Neu.\xa0Zone Faceoffs','Off.\xa0Zone Faceoff %'],axis=1)
                        
df_0708.head()
# Out:
#           Player  GP         TOI    CF%    FF%    SF%    GF%   SCF%  HDCF%  \
# 0   Aaron Downey  56  256.933333  50.65  51.12  50.22  46.15  45.09  46.05
# 1  Aaron Johnson  30  415.850000  51.46  49.52  50.26  55.26  52.16  46.09
# 2   Aaron Miller  57  988.183333  40.09  40.17  40.23  40.24  41.50  42.39
# 3     Aaron Rome  17  309.033333  48.16  49.16  48.70  30.00  52.09  50.55
# 4    Aaron Voros  55  504.600000  48.88  47.32  46.98  50.00  49.63  51.59
#
#    HDGF%    PDO  Off Zone Faceoff %  Def Zone Faceoff %  Neu Zone Faceoff %
# 0  50.00  0.991           53.886010           11.398964           34.715026
# 1  47.06  1.020           32.763533           25.925926           41.310541
# 2  37.50  1.000           20.942408           39.005236           40.052356
# 3  27.27  0.944           24.472574           34.599156           40.928270
# 4  57.14  1.013           31.163708           28.402367           40.433925

# %%
df_0809['Off Zone Faceoff %'] = df_0809['Off.\xa0Zone Faceoffs']*100/(df_0809['Off.\xa0Zone Faceoffs'] + df_0809['Neu.\xa0Zone Faceoffs'] + df_0809['Def.\xa0Zone Faceoffs'])
df_0809['Def Zone Faceoff %'] = df_0809['Def.\xa0Zone Faceoffs']*100/(df_0809['Off.\xa0Zone Faceoffs'] + df_0809['Neu.\xa0Zone Faceoffs'] + df_0809['Def.\xa0Zone Faceoffs'])
df_0809['Neu Zone Faceoff %'] = df_0809['Neu.\xa0Zone Faceoffs']*100/(df_0809['Off.\xa0Zone Faceoffs'] + df_0809['Neu.\xa0Zone Faceoffs'] + df_0809['Def.\xa0Zone Faceoffs'])
df_0910['Off Zone Faceoff %'] = df_0910['Off.\xa0Zone Faceoffs']*100/(df_0910['Off.\xa0Zone Faceoffs'] + df_0910['Neu.\xa0Zone Faceoffs'] + df_0910['Def.\xa0Zone Faceoffs'])
df_0910['Def Zone Faceoff %'] = df_0910['Def.\xa0Zone Faceoffs']*100/(df_0910['Off.\xa0Zone Faceoffs'] + df_0910['Neu.\xa0Zone Faceoffs'] + df_0910['Def.\xa0Zone Faceoffs'])
df_0910['Neu Zone Faceoff %'] = df_0910['Neu.\xa0Zone Faceoffs']*100/(df_0910['Off.\xa0Zone Faceoffs'] + df_0910['Neu.\xa0Zone Faceoffs'] + df_0910['Def.\xa0Zone Faceoffs'])
df_1011['Off Zone Faceoff %'] = df_1011['Off.\xa0Zone Faceoffs']*100/(df_1011['Off.\xa0Zone Faceoffs'] + df_1011['Neu.\xa0Zone Faceoffs'] + df_1011['Def.\xa0Zone Faceoffs'])
df_1011['Def Zone Faceoff %'] = df_1011['Def.\xa0Zone Faceoffs']*100/(df_1011['Off.\xa0Zone Faceoffs'] + df_1011['Neu.\xa0Zone Faceoffs'] + df_1011['Def.\xa0Zone Faceoffs'])
df_1011['Neu Zone Faceoff %'] = df_1011['Neu.\xa0Zone Faceoffs']*100/(df_1011['Off.\xa0Zone Faceoffs'] + df_1011['Neu.\xa0Zone Faceoffs'] + df_1011['Def.\xa0Zone Faceoffs'])
df_1112['Off Zone Faceoff %'] = df_1112['Off.\xa0Zone Faceoffs']*100/(df_1112['Off.\xa0Zone Faceoffs'] + df_1112['Neu.\xa0Zone Faceoffs'] + df_1112['Def.\xa0Zone Faceoffs'])
df_1112['Def Zone Faceoff %'] = df_1112['Def.\xa0Zone Faceoffs']*100/(df_1112['Off.\xa0Zone Faceoffs'] + df_1112['Neu.\xa0Zone Faceoffs'] + df_1112['Def.\xa0Zone Faceoffs'])
df_1112['Neu Zone Faceoff %'] = df_1112['Neu.\xa0Zone Faceoffs']*100/(df_1112['Off.\xa0Zone Faceoffs'] + df_1112['Neu.\xa0Zone Faceoffs'] + df_1112['Def.\xa0Zone Faceoffs'])
df_1213['Off Zone Faceoff %'] = df_1213['Off.\xa0Zone Faceoffs']*100/(df_1213['Off.\xa0Zone Faceoffs'] + df_1213['Neu.\xa0Zone Faceoffs'] + df_1213['Def.\xa0Zone Faceoffs'])
df_1213['Def Zone Faceoff %'] = df_1213['Def.\xa0Zone Faceoffs']*100/(df_1213['Off.\xa0Zone Faceoffs'] + df_1213['Neu.\xa0Zone Faceoffs'] + df_1213['Def.\xa0Zone Faceoffs'])
df_1213['Neu Zone Faceoff %'] = df_1213['Neu.\xa0Zone Faceoffs']*100/(df_1213['Off.\xa0Zone Faceoffs'] + df_1213['Neu.\xa0Zone Faceoffs'] + df_1213['Def.\xa0Zone Faceoffs'])
df_1314['Off Zone Faceoff %'] = df_1314['Off.\xa0Zone Faceoffs']*100/(df_1314['Off.\xa0Zone Faceoffs'] + df_1314['Neu.\xa0Zone Faceoffs'] + df_1314['Def.\xa0Zone Faceoffs'])
df_1314['Def Zone Faceoff %'] = df_1314['Def.\xa0Zone Faceoffs']*100/(df_1314['Off.\xa0Zone Faceoffs'] + df_1314['Neu.\xa0Zone Faceoffs'] + df_1314['Def.\xa0Zone Faceoffs'])
df_1314['Neu Zone Faceoff %'] = df_1314['Neu.\xa0Zone Faceoffs']*100/(df_1314['Off.\xa0Zone Faceoffs'] + df_1314['Neu.\xa0Zone Faceoffs'] + df_1314['Def.\xa0Zone Faceoffs'])
df_1415['Off Zone Faceoff %'] = df_1415['Off.\xa0Zone Faceoffs']*100/(df_1415['Off.\xa0Zone Faceoffs'] + df_1415['Neu.\xa0Zone Faceoffs'] + df_1415['Def.\xa0Zone Faceoffs'])
df_1415['Def Zone Faceoff %'] = df_1415['Def.\xa0Zone Faceoffs']*100/(df_1415['Off.\xa0Zone Faceoffs'] + df_1415['Neu.\xa0Zone Faceoffs'] + df_1415['Def.\xa0Zone Faceoffs'])
df_1415['Neu Zone Faceoff %'] = df_1415['Neu.\xa0Zone Faceoffs']*100/(df_1415['Off.\xa0Zone Faceoffs'] + df_1415['Neu.\xa0Zone Faceoffs'] + df_1415['Def.\xa0Zone Faceoffs'])
df_1516['Off Zone Faceoff %'] = df_1516['Off.\xa0Zone Faceoffs']*100/(df_1516['Off.\xa0Zone Faceoffs'] + df_1516['Neu.\xa0Zone Faceoffs'] + df_1516['Def.\xa0Zone Faceoffs'])
df_1516['Def Zone Faceoff %'] = df_1516['Def.\xa0Zone Faceoffs']*100/(df_1516['Off.\xa0Zone Faceoffs'] + df_1516['Neu.\xa0Zone Faceoffs'] + df_1516['Def.\xa0Zone Faceoffs'])
df_1516['Neu Zone Faceoff %'] = df_1516['Neu.\xa0Zone Faceoffs']*100/(df_1516['Off.\xa0Zone Faceoffs'] + df_1516['Neu.\xa0Zone Faceoffs'] + df_1516['Def.\xa0Zone Faceoffs'])
df_1617['Off Zone Faceoff %'] = df_1617['Off.\xa0Zone Faceoffs']*100/(df_1617['Off.\xa0Zone Faceoffs'] + df_1617['Neu.\xa0Zone Faceoffs'] + df_1617['Def.\xa0Zone Faceoffs'])
df_1617['Def Zone Faceoff %'] = df_1617['Def.\xa0Zone Faceoffs']*100/(df_1617['Off.\xa0Zone Faceoffs'] + df_1617['Neu.\xa0Zone Faceoffs'] + df_1617['Def.\xa0Zone Faceoffs'])
df_1617['Neu Zone Faceoff %'] = df_1617['Neu.\xa0Zone Faceoffs']*100/(df_1617['Off.\xa0Zone Faceoffs'] + df_1617['Neu.\xa0Zone Faceoffs'] + df_1617['Def.\xa0Zone Faceoffs'])
df_1718['Off Zone Faceoff %'] = df_1718['Off.\xa0Zone Faceoffs']*100/(df_1718['Off.\xa0Zone Faceoffs'] + df_1718['Neu.\xa0Zone Faceoffs'] + df_1718['Def.\xa0Zone Faceoffs'])
df_1718['Def Zone Faceoff %'] = df_1718['Def.\xa0Zone Faceoffs']*100/(df_1718['Off.\xa0Zone Faceoffs'] + df_1718['Neu.\xa0Zone Faceoffs'] + df_1718['Def.\xa0Zone Faceoffs'])
df_1718['Neu Zone Faceoff %'] = df_1718['Neu.\xa0Zone Faceoffs']*100/(df_1718['Off.\xa0Zone Faceoffs'] + df_1718['Neu.\xa0Zone Faceoffs'] + df_1718['Def.\xa0Zone Faceoffs'])

df_0809 = df_0809.drop(['Off.\xa0Zone Faceoffs','Def.\xa0Zone Faceoffs','Neu.\xa0Zone Faceoffs','Off.\xa0Zone Faceoff %'],axis=1)
df_0910 = df_0910.drop(['Off.\xa0Zone Faceoffs','Def.\xa0Zone Faceoffs','Neu.\xa0Zone Faceoffs','Off.\xa0Zone Faceoff %'],axis=1)
df_1011 = df_1011.drop(['Off.\xa0Zone Faceoffs','Def.\xa0Zone Faceoffs','Neu.\xa0Zone Faceoffs','Off.\xa0Zone Faceoff %'],axis=1)
df_1112 = df_1112.drop(['Off.\xa0Zone Faceoffs','Def.\xa0Zone Faceoffs','Neu.\xa0Zone Faceoffs','Off.\xa0Zone Faceoff %'],axis=1)
df_1213 = df_1213.drop(['Off.\xa0Zone Faceoffs','Def.\xa0Zone Faceoffs','Neu.\xa0Zone Faceoffs','Off.\xa0Zone Faceoff %'],axis=1)
df_1314 = df_1314.drop(['Off.\xa0Zone Faceoffs','Def.\xa0Zone Faceoffs','Neu.\xa0Zone Faceoffs','Off.\xa0Zone Faceoff %'],axis=1)
df_1415 = df_1415.drop(['Off.\xa0Zone Faceoffs','Def.\xa0Zone Faceoffs','Neu.\xa0Zone Faceoffs','Off.\xa0Zone Faceoff %'],axis=1)
df_1516 = df_1516.drop(['Off.\xa0Zone Faceoffs','Def.\xa0Zone Faceoffs','Neu.\xa0Zone Faceoffs','Off.\xa0Zone Faceoff %'],axis=1)
df_1617 = df_1617.drop(['Off.\xa0Zone Faceoffs','Def.\xa0Zone Faceoffs','Neu.\xa0Zone Faceoffs','Off.\xa0Zone Faceoff %'],axis=1)
df_1718 = df_1718.drop(['Off.\xa0Zone Faceoffs','Def.\xa0Zone Faceoffs','Neu.\xa0Zone Faceoffs','Off.\xa0Zone Faceoff %'],axis=1)

df_1718.head()
# Out:
#             Player  GP          TOI    CF%    FF%    SF%    GF%   SCF%  HDCF%  \
# 0       A.J. Greer  17   125.683333  40.55  40.48  42.52  66.67  46.00  39.53
# 1     Aaron Ekblad  82  1917.900000  48.74  48.76  48.06  52.75  49.16  44.10
# 2       Aaron Ness   8   101.816667  41.27  41.18  43.24  54.55  40.86  22.58
# 3  Adam Clendening   5    79.666667  46.47  47.69  47.87  40.00  42.22  42.86
# 4   Adam Cracknell   5    38.550000  42.86  38.30  36.84   0.00  34.78  30.00
#
#    HDGF%    PDO  Off Zone Faceoff %  Def Zone Faceoff %  Neu Zone Faceoff %
# 0  66.67  1.047           34.951456           32.038835           33.009709
# 1  49.57  1.018           28.571429           40.973817           30.454754
# 2  25.00  1.046           22.471910           35.955056           41.573034
# 3  42.86  0.966           28.378378           33.783784           37.837838
# 4   0.00  0.917           23.333333           40.000000           36.666667

# %%
# Again, let's see if any data is missing

df_0708.info()
df_0809.info()
df_0910.info()
df_1011.info()
df_1112.info()
df_1213.info()
df_1314.info()
df_1415.info()
df_1516.info()
df_1617.info()
df_1718.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 14 columns):
# Player                852 non-null object
# GP                    852 non-null int64
# TOI                   852 non-null float64
# CF%                   852 non-null float64
# FF%                   852 non-null float64
# SF%                   852 non-null float64
# GF%                   852 non-null float64
# SCF%                  852 non-null float64
# HDCF%                 852 non-null float64
# HDGF%                 852 non-null float64
# PDO                   852 non-null float64
# Off Zone Faceoff %    852 non-null float64
# Def Zone Faceoff %    852 non-null float64
# Neu Zone Faceoff %    852 non-null float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 93.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885 entries, 0 to 884
# Data columns (total 14 columns):
# Player                885 non-null object
# ...

# %% [markdown]
# Again, looks good.

# %%
# Now I'll load the rest of the statistics

df_0708_ind = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2007-8 ind.csv')

df_0708_ind.head()
# Out:
#    Unnamed: 0         Player Team Position  GP         TOI  Goals  \
# 0         NaN   Aaron Downey  DET        R  56  256.933333      0
# 1         NaN  Aaron Johnson  NYI        D  30  415.850000      0
# 2         NaN   Aaron Miller  VAN        D  57  988.183333      1
# 3         NaN     Aaron Rome  CBJ        D  17  309.033333      1
# 4         NaN    Aaron Voros  MIN        L  55  504.600000      7
#
#    Total Assists  First Assists  Second Assists     ...      Misconduct  \
# 0              3              3               0     ...               2
# 1              2              0               2     ...               0
# 2              8              1               7     ...               1
# 3              1              0               1     ...               1
# 4              7              6               1     ...               2
#
#    Penalties Drawn  Giveaways  Takeaways  Hits  Hits Taken  Shots Blocked  \
# ...

# %%
df_0708_ind = df_0708_ind.drop(df_0708_ind.columns[0], axis=1)

df_0708_ind.head()
# Out:
#           Player Team Position  GP         TOI  Goals  Total Assists  \
# 0   Aaron Downey  DET        R  56  256.933333      0              3
# 1  Aaron Johnson  NYI        D  30  415.850000      0              2
# 2   Aaron Miller  VAN        D  57  988.183333      1              8
# 3     Aaron Rome  CBJ        D  17  309.033333      1              1
# 4    Aaron Voros  MIN        L  55  504.600000      7              7
#
#    First Assists  Second Assists  Total Points     ...      Misconduct  \
# 0              3               0             3     ...               2
# 1              0               2             2     ...               0
# 2              1               7             9     ...               1
# 3              0               1             2     ...               1
# 4              6               1            14     ...               2
#
#    Penalties Drawn  Giveaways  Takeaways  Hits  Hits Taken  Shots Blocked  \
# ...

# %%
df_0809_ind = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2008-9 ind.csv')
df_0910_ind = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2009-10 ind.csv')
df_1011_ind = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2010-11 ind.csv')
df_1112_ind = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2011-12 ind.csv')
df_1213_ind = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2012-13 ind.csv')
df_1314_ind = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2013-14 ind.csv')
df_1415_ind = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2014-15 ind.csv')
df_1516_ind = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2015-16 ind.csv')
df_1617_ind = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2016-17 ind.csv')
df_1718_ind = pd.read_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Player Season Totals 2017-18 ind.csv')

df_0809_ind = df_0809_ind.drop(df_0809_ind.columns[0], axis=1)
df_0910_ind = df_0910_ind.drop(df_0910_ind.columns[0], axis=1)
df_1011_ind = df_1011_ind.drop(df_1011_ind.columns[0], axis=1)
df_1112_ind = df_1112_ind.drop(df_1112_ind.columns[0], axis=1)
df_1213_ind = df_1213_ind.drop(df_1213_ind.columns[0], axis=1)
df_1314_ind = df_1314_ind.drop(df_1314_ind.columns[0], axis=1)
df_1415_ind = df_1415_ind.drop(df_1415_ind.columns[0], axis=1)
df_1516_ind = df_1516_ind.drop(df_1516_ind.columns[0], axis=1)
df_1617_ind = df_1617_ind.drop(df_1617_ind.columns[0], axis=1)
df_1718_ind = df_1718_ind.drop(df_1718_ind.columns[0], axis=1)

# Last time, look at another one

df_1718_ind.head()
# Out:
#             Player      Team Position  GP          TOI  Goals  Total Assists  \
# 0       A.J. Greer       COL        L  17   125.683333      0              3
# 1     Aaron Ekblad       FLA        D  82  1917.900000     16             22
# 2       Aaron Ness       WSH        D   8   101.816667      0              1
# 3  Adam Clendening       ARI        D   5    79.666667      0              2
# 4   Adam Cracknell  DAL, NYR        R   5    38.550000      0              0
#
#    First Assists  Second Assists  Total Points     ...      Misconduct  \
# 0              2               1             3     ...               1
# 1              6              16            38     ...               0
# 2              0               1             1     ...               0
# 3              0               2             2     ...               0
# 4              0               0             0     ...               0
#
# ...

# %%
df_0708_ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 32 columns):
# Player              852 non-null object
# Team                852 non-null object
# Position            852 non-null object
# GP                  852 non-null int64
# TOI                 852 non-null float64
# Goals               852 non-null int64
# Total Assists       852 non-null int64
# First Assists       852 non-null int64
# Second Assists      852 non-null int64
# Total Points        852 non-null int64
# Shots               852 non-null int64
# SH%                 852 non-null float64
# iCF                 852 non-null int64
# iFF                 852 non-null int64
# iSCF                852 non-null int64
# iHDCF               852 non-null int64
# Rush Attempts       852 non-null int64
# Rebounds Created    852 non-null int64
# PIM                 852 non-null int64
# Total Penalties     852 non-null int64
# Minor               852 non-null int64
# ...

# %%
# I already have the player data in the bio dataframe, and for this study, I don't need the i columns, the assist or penalty
# breakdowns or the non percentage faceoff numbers

df_0708_ind = df_0708_ind.drop(['Team','Position','GP','TOI','First Assists','Second Assists','iCF','iFF','iSCF','iHDCF','Total Penalties','Minor','Major','Misconduct','Faceoffs Won','Faceoffs Lost'], axis=1)

df_0708_ind.head()
# Out:
#           Player  Goals  Total Assists  Total Points  Shots    SH%  \
# 0   Aaron Downey      0              3             3     15   0.00
# 1  Aaron Johnson      0              2             2     16   0.00
# 2   Aaron Miller      1              8             9     27   3.70
# 3     Aaron Rome      1              1             2     15   6.67
# 4    Aaron Voros      7              7            14     52  13.46
#
#    Rush Attempts  Rebounds Created  PIM  Penalties Drawn  Giveaways  \
# 0              0                 1  116               21          4
# 1              0                 1   30                4         16
# 2              1                 5   32                4         29
# 3              0                 2   33                5          4
# 4              4                 8  141               32         10
#
#    Takeaways  Hits  Hits Taken  Shots Blocked Faceoffs %
# 0          3    79          48              6          -
# ...

# %%
df_0809_ind = df_0809_ind.drop(['Team','Position','GP','TOI','First Assists','Second Assists','iCF','iFF','iSCF','iHDCF','Total Penalties','Minor','Major','Misconduct','Faceoffs Won','Faceoffs Lost'], axis=1)
df_0910_ind = df_0910_ind.drop(['Team','Position','GP','TOI','First Assists','Second Assists','iCF','iFF','iSCF','iHDCF','Total Penalties','Minor','Major','Misconduct','Faceoffs Won','Faceoffs Lost'], axis=1)
df_1011_ind = df_1011_ind.drop(['Team','Position','GP','TOI','First Assists','Second Assists','iCF','iFF','iSCF','iHDCF','Total Penalties','Minor','Major','Misconduct','Faceoffs Won','Faceoffs Lost'], axis=1)
df_1112_ind = df_1112_ind.drop(['Team','Position','GP','TOI','First Assists','Second Assists','iCF','iFF','iSCF','iHDCF','Total Penalties','Minor','Major','Misconduct','Faceoffs Won','Faceoffs Lost'], axis=1)
df_1213_ind = df_1213_ind.drop(['Team','Position','GP','TOI','First Assists','Second Assists','iCF','iFF','iSCF','iHDCF','Total Penalties','Minor','Major','Misconduct','Faceoffs Won','Faceoffs Lost'], axis=1)
df_1314_ind = df_1314_ind.drop(['Team','Position','GP','TOI','First Assists','Second Assists','iCF','iFF','iSCF','iHDCF','Total Penalties','Minor','Major','Misconduct','Faceoffs Won','Faceoffs Lost'], axis=1)
df_1415_ind = df_1415_ind.drop(['Team','Position','GP','TOI','First Assists','Second Assists','iCF','iFF','iSCF','iHDCF','Total Penalties','Minor','Major','Misconduct','Faceoffs Won','Faceoffs Lost'], axis=1)
df_1516_ind = df_1516_ind.drop(['Team','Position','GP','TOI','First Assists','Second Assists','iCF','iFF','iSCF','iHDCF','Total Penalties','Minor','Major','Misconduct','Faceoffs Won','Faceoffs Lost'], axis=1)
df_1617_ind = df_1617_ind.drop(['Team','Position','GP','TOI','First Assists','Second Assists','iCF','iFF','iSCF','iHDCF','Total Penalties','Minor','Major','Misconduct','Faceoffs Won','Faceoffs Lost'], axis=1)
df_1718_ind = df_1718_ind.drop(['Team','Position','GP','TOI','First Assists','Second Assists','iCF','iFF','iSCF','iHDCF','Total Penalties','Minor','Major','Misconduct','Faceoffs Won','Faceoffs Lost'], axis=1)

df_1718_ind.head()
# Out:
#             Player  Goals  Total Assists  Total Points  Shots   SH%  \
# 0       A.J. Greer      0              3             3     13  0.00
# 1     Aaron Ekblad     16             22            38    189  8.47
# 2       Aaron Ness      0              1             1      2  0.00
# 3  Adam Clendening      0              2             2      4  0.00
# 4   Adam Cracknell      0              0             0      6  0.00
#
#    Rush Attempts  Rebounds Created  PIM  Penalties Drawn  Giveaways  \
# 0              1                 0   29                7          2
# 1              4                17   71               12         99
# 2              0                 0    8                1          2
# 3              0                 0    2                0          4
# 4              1                 0    0                0          2
#
#    Takeaways  Hits  Hits Taken  Shots Blocked Faceoffs %
# 0          3    30          16              5      33.33
# ...

# %%
df_0708_ind.info()
df_0809_ind.info()
df_0910_ind.info()
df_1011_ind.info()
df_1112_ind.info()
df_1213_ind.info()
df_1314_ind.info()
df_1415_ind.info()
df_1516_ind.info()
df_1617_ind.info()
df_1718_ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 16 columns):
# Player              852 non-null object
# Goals               852 non-null int64
# Total Assists       852 non-null int64
# Total Points        852 non-null int64
# Shots               852 non-null int64
# SH%                 852 non-null float64
# Rush Attempts       852 non-null int64
# Rebounds Created    852 non-null int64
# PIM                 852 non-null int64
# Penalties Drawn     852 non-null int64
# Giveaways           852 non-null int64
# Takeaways           852 non-null int64
# Hits                852 non-null int64
# Hits Taken          852 non-null int64
# Shots Blocked       852 non-null int64
# Faceoffs %          852 non-null object
# dtypes: float64(1), int64(13), object(2)
# memory usage: 106.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885 entries, 0 to 884
# Data columns (total 16 columns):
# Player              885 non-null object
# ...

# %% [markdown]
# Good, again everything looks again.

# %%
# Now let's make sure all the dataframes are the same length for merging

print('0708',len(df_0708) == len(df_0708_ind) == len(df_bio_0708))
print('0809',len(df_0809) == len(df_0809_ind) == len(df_bio_0809))
print('0910',len(df_0910) == len(df_0910_ind) == len(df_bio_0910))
print('1011',len(df_1011) == len(df_1011_ind) == len(df_bio_1011))
print('1112',len(df_1112) == len(df_1112_ind) == len(df_bio_1112))
print('1213',len(df_1213) == len(df_1213_ind) == len(df_bio_1213))
print('1314',len(df_1314) == len(df_1314_ind) == len(df_bio_1314))
print('1415',len(df_1415) == len(df_1415_ind) == len(df_bio_1415))
print('1516',len(df_1516) == len(df_1516_ind) == len(df_bio_1516))
print('1617',len(df_1617) == len(df_1617_ind) == len(df_bio_1617))
print('1718',len(df_1718) == len(df_1718_ind) == len(df_bio_1718))
# Out:
# 0708 True
# 0809 True
# 0910 True
# 1011 True
# 1112 True
# 1213 True
# 1314 True
# 1415 True
# 1516 True
# 1617 True
# 1718 True

# %% [markdown]
# OK, everything looks good to merge.

# %%
df_0708 = pd.merge(pd.merge(df_bio_0708,df_0708,on='Player'),df_0708_ind,on='Player')
df_0708.head()
# Out:
#           Player Team Position Date of Birth Nationality  Height (in)  \
# 0   Aaron Downey  DET        R    1974-08-27         CAN           73
# 1  Aaron Johnson  NYI        D    1983-04-30         CAN           73
# 2   Aaron Miller  VAN        D    1971-08-11         USA           75
# 3     Aaron Rome  CBJ        D    1983-09-27         CAN           73
# 4    Aaron Voros  MIN        L    1981-07-02         CAN           74
#
#    Weight (lbs) Draft Year Draft Round  GP     ...      Rush Attempts  \
# 0           215          -           -  56     ...                  0
# 1           204       2001           3  30     ...                  0
# 2           210       1989           5  57     ...                  1
# 3           220       2002           4  17     ...                  0
# 4           210       2001           8  55     ...                  4
#
#    Rebounds Created  PIM  Penalties Drawn  Giveaways  Takeaways  Hits  \
# ...

# %%
df_0708.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 858 entries, 0 to 857
# Data columns (total 37 columns):
# Player                858 non-null object
# Team                  858 non-null object
# Position              858 non-null object
# Date of Birth         858 non-null object
# Nationality           858 non-null object
# Height (in)           858 non-null int64
# Weight (lbs)          858 non-null int64
# Draft Year            858 non-null object
# Draft Round           858 non-null object
# GP                    858 non-null int64
# TOI                   858 non-null float64
# CF%                   858 non-null float64
# FF%                   858 non-null float64
# SF%                   858 non-null float64
# GF%                   858 non-null float64
# SCF%                  858 non-null float64
# HDCF%                 858 non-null float64
# HDGF%                 858 non-null float64
# PDO                   858 non-null float64
# Off Zone Faceoff %    858 non-null float64
# ...

# %%
df_0809 = pd.merge(pd.merge(df_bio_0809,df_0809,on='Player'),df_0809_ind,on='Player')
df_0910 = pd.merge(pd.merge(df_bio_0910,df_0910,on='Player'),df_0910_ind,on='Player')
df_1011 = pd.merge(pd.merge(df_bio_1011,df_1011,on='Player'),df_1011_ind,on='Player')
df_1112 = pd.merge(pd.merge(df_bio_1112,df_1112,on='Player'),df_1112_ind,on='Player')
df_1213 = pd.merge(pd.merge(df_bio_1213,df_1213,on='Player'),df_1213_ind,on='Player')
df_1314 = pd.merge(pd.merge(df_bio_1314,df_1314,on='Player'),df_1314_ind,on='Player')
df_1415 = pd.merge(pd.merge(df_bio_1415,df_1415,on='Player'),df_1415_ind,on='Player')
df_1516 = pd.merge(pd.merge(df_bio_1516,df_1516,on='Player'),df_1516_ind,on='Player')
df_1617 = pd.merge(pd.merge(df_bio_1617,df_1617,on='Player'),df_1617_ind,on='Player')
df_1718 = pd.merge(pd.merge(df_bio_1718,df_1718,on='Player'),df_1718_ind,on='Player')

# And the usual last inspection

df_1718.head()
# Out:
#             Player      Team Position Date of Birth Nationality  Height (in)  \
# 0       A.J. Greer       COL        L    1996-12-14         CAN           75
# 1     Aaron Ekblad       FLA        D    1996-02-07         CAN           76
# 2       Aaron Ness       WSH        D    1990-05-18         USA           70
# 3  Adam Clendening       ARI        D    1992-10-26         USA           72
# 4   Adam Cracknell  DAL, NYR        R    1985-07-15         CAN           74
#
#    Weight (lbs) Draft Year Draft Round  GP     ...      Rush Attempts  \
# 0           204       2015           2  17     ...                  1
# 1           216       2014           1  82     ...                  4
# 2           184       2008           2   8     ...                  0
# 3           196       2011           2   5     ...                  0
# 4           218       2004           9   5     ...                  1
#
#    Rebounds Created  PIM  Penalties Drawn  Giveaways  Takeaways  Hits  \
# ...

# %%
df_1718.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 896 entries, 0 to 895
# Data columns (total 37 columns):
# Player                896 non-null object
# Team                  896 non-null object
# Position              896 non-null object
# Date of Birth         896 non-null object
# Nationality           896 non-null object
# Height (in)           896 non-null int64
# Weight (lbs)          896 non-null int64
# Draft Year            896 non-null object
# Draft Round           896 non-null object
# GP                    896 non-null int64
# TOI                   896 non-null float64
# CF%                   896 non-null float64
# FF%                   896 non-null float64
# SF%                   896 non-null float64
# GF%                   896 non-null float64
# SCF%                  896 non-null float64
# HDCF%                 896 non-null float64
# HDGF%                 896 non-null float64
# PDO                   896 non-null float64
# Off Zone Faceoff %    896 non-null float64
# ...

# %%
# Now, add the season info to each dataframe to concatenate all the data into one complete dataframe

df_0708['Season'] = '2007-2008'
df_0708.head()
# Out:
#           Player Team Position Date of Birth Nationality  Height (in)  \
# 0   Aaron Downey  DET        R    1974-08-27         CAN           73
# 1  Aaron Johnson  NYI        D    1983-04-30         CAN           73
# 2   Aaron Miller  VAN        D    1971-08-11         USA           75
# 3     Aaron Rome  CBJ        D    1983-09-27         CAN           73
# 4    Aaron Voros  MIN        L    1981-07-02         CAN           74
#
#    Weight (lbs) Draft Year Draft Round  GP    ...      Rebounds Created  PIM  \
# 0           215          -           -  56    ...                     1  116
# 1           204       2001           3  30    ...                     1   30
# 2           210       1989           5  57    ...                     5   32
# 3           220       2002           4  17    ...                     2   33
# 4           210       2001           8  55    ...                     8  141
#
#    Penalties Drawn  Giveaways  Takeaways  Hits  Hits Taken  Shots Blocked  \
# ...

# %%
df_0809['Season'] = '2008-2009'
df_0910['Season'] = '2009-2010'
df_1011['Season'] = '2010-2011'
df_1112['Season'] = '2011-2012'
df_1213['Season'] = '2012-2013'
df_1314['Season'] = '2013-2014'
df_1415['Season'] = '2014-2015'
df_1516['Season'] = '2015-2016'
df_1617['Season'] = '2016-2017'
df_1718['Season'] = '2017-2018'

# And again the usual last inspection

df_1718.head()
# Out:
#             Player      Team Position Date of Birth Nationality  Height (in)  \
# 0       A.J. Greer       COL        L    1996-12-14         CAN           75
# 1     Aaron Ekblad       FLA        D    1996-02-07         CAN           76
# 2       Aaron Ness       WSH        D    1990-05-18         USA           70
# 3  Adam Clendening       ARI        D    1992-10-26         USA           72
# 4   Adam Cracknell  DAL, NYR        R    1985-07-15         CAN           74
#
#    Weight (lbs) Draft Year Draft Round  GP    ...      Rebounds Created  PIM  \
# 0           204       2015           2  17    ...                     0   29
# 1           216       2014           1  82    ...                    17   71
# 2           184       2008           2   8    ...                     0    8
# 3           196       2011           2   5    ...                     0    2
# 4           218       2004           9   5    ...                     0    0
#
# ...

# %%
all_data = [df_0708, df_0809, df_0910, df_1011, df_1112, df_1213, df_1314, df_1415, df_1516, df_1617, df_1718]

df_all_data = pd.concat(all_data, ignore_index=True)

df_all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9706 entries, 0 to 9705
# Data columns (total 38 columns):
# Player                9706 non-null object
# Team                  9706 non-null object
# Position              9706 non-null object
# Date of Birth         9706 non-null object
# Nationality           9706 non-null object
# Height (in)           9706 non-null int64
# Weight (lbs)          9706 non-null int64
# Draft Year            9706 non-null object
# Draft Round           9706 non-null object
# GP                    9706 non-null int64
# TOI                   9706 non-null float64
# CF%                   9706 non-null float64
# FF%                   9706 non-null float64
# SF%                   9706 non-null float64
# GF%                   9706 non-null float64
# SCF%                  9706 non-null float64
# HDCF%                 9706 non-null float64
# HDGF%                 9706 non-null float64
# PDO                   9706 non-null float64
# ...

# %%
# Excellent.  Now save for future work.

df_all_data.to_csv('C:/Users/Hill HP 2015/Documents/Springboard/Capstone Project 2/data/Complete Data.csv', encoding='utf-8')
